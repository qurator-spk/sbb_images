# %%
# !ls experiment2
# Out:
# data
# experiment2
# iconclass-b16-yfcc-msclips_epochs10_as1_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl
# iconclass-b16-yfcc-msclips_epochs10_as1_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pth
# iconclass-b16-yfcc-msclips_epochs10_as2_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl
# iconclass.sqlite

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle('experiment2/iconclass-b16-yfcc-msclips_epochs10_as2_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')
df
# Out:
#          lr0    trloss  update_counter     elapsed
# 0   0.000500  8.717391               0    4.357910
# 1   0.000500  8.359312               0    5.487114
# 2   0.000500  6.102049               1    6.718218
# 3   0.000500  6.354572               1    7.840302
# 4   0.000500  4.455236               2    9.043714
# ..       ...       ...             ...         ...
# 94  0.000494  4.159255              47  114.442140
# 95  0.000494  4.159301              47  115.564587
# 96  0.000494  4.159224              48  116.767154
# 97  0.000494  4.159310              48  117.890214
# 98  0.000494  4.159315              49  119.106895
#
# [99 rows x 4 columns]

# %%
def plot_train(file):
    
    df = pd.read_pickle(file)
    
    base_size=10
    fig, ax1 = plt.subplots(figsize=(base_size,int(34/55*base_size)))
    
    ax2 = ax1.twinx()  
    ax3 = ax1.twinx()
    ax4 = ax1.twinx()
    
    ax3.spines['right'].set_position(('outward', 60))
    ax4.spines['right'].set_position(('outward', 120))
    
    color = 'r'
    ax1.set_xlabel('batch iteration')
    ax1.set_ylabel('lr0', color=color)
    ax1.plot(df['lr0'], color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    
    color = 'b'
    ax2.set_ylabel('trloss', color=color)  
    ax2.plot(df['trloss'].rolling(100).mean(), color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    
    color = 'g'
    ax3.set_ylabel('elapsed(hr)', color=color)  
    ax3.plot(df['elapsed']/3600, color=color)
    ax3.tick_params(axis='y', labelcolor=color)
    
    color = 'k'
    ax4.set_ylabel('#updates', color=color)  
    ax4.plot(df['update_counter'], 'k-.')
    ax4.tick_params(axis='y', labelcolor=color)
    

    fig.tight_layout()  
    plt.show()

# %% [markdown]
# # CosineAnnealingWarmRestarts

# %% [markdown]
# ## batch size 64

# %%
plot_train('experiment2/iconclass-b16-yfcc-msclips_epochs10_as1_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 128

# %%
plot_train('experiment2/iconclass-b16-yfcc-msclips_epochs10_as2_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 256

# %%
plot_train('experiment2/iconclass-b16-yfcc-msclips_epochs10_as4_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 512

# %%
plot_train('experiment2/iconclass-b16-yfcc-msclips_epochs10_as8_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 1024

# %%
plot_train('experiment2/iconclass-b16-yfcc-msclips_epochs10_as16_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# # StepLR

# %% [markdown]
# ## batch size 64

# %%
plot_train('experiment2/iconclass-b16-yfcc-msclips_epochs10_as1_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 128

# %%
plot_train('experiment2/iconclass-b16-yfcc-msclips_epochs10_as2_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 256

# %%
plot_train('experiment2/iconclass-b16-yfcc-msclips_epochs10_as4_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 512

# %%
plot_train('experiment2/iconclass-b16-yfcc-msclips_epochs10_as8_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 1024

# %%
plot_train('experiment2/iconclass-b16-yfcc-msclips_epochs10_as16_start-lr5e-4_lr-schedStepLR.pkl')
