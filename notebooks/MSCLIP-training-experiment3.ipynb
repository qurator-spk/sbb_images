# %%
# !ls experiment3
# Out:
# data
# experiment3
# iconclass-b16-yfcc-msclips_epochs10_as1_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl
# iconclass.sqlite

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle('experiment3/iconclass-b16-yfcc-msclips_epochs10_as1_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')
df.tail()
# Out:
#           telr0     imlr0    trloss  trloss_te  trloss_im  update_counter  \
# 12494  0.000456  0.000456  2.821932   2.831890   2.811973           12494
# 12495  0.000455  0.000455  2.975845   2.960582   2.991108           12495
# 12496  0.000455  0.000455  2.726659   2.715919   2.737399           12496
# 12497  0.000455  0.000455  2.618527   2.609842   2.627213           12497
# 12498  0.000454  0.000454  2.900490   2.904251   2.896729           12498
#
#             elapsed
# 12494  15224.477611
# 12495  15225.707227
# 12496  15226.920368
# 12497  15228.139812
# 12498  15229.348945

# %%
def plot_train(file):
    
    df = pd.read_pickle(file).iloc[100:]
    
    base_size=10
    fig, ax1 = plt.subplots(figsize=(base_size,int(34/55*base_size)))
    
    ax2 = ax1.twinx()  
    ax3 = ax1.twinx()
    ax4 = ax1.twinx()
    
    ax3.spines['right'].set_position(('outward', 60))
    ax4.spines['right'].set_position(('outward', 120))
    
    window_size=50
    
    color = 'r'
    ax1.set_xlabel('batch iteration')
    ax1.set_ylabel('telr0', color=color)
    ax1.plot(df['telr0'], color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    
    color = 'b'
    ax2.set_ylabel('trloss', color=color)  
    ax2.plot(df['trloss'].rolling(window_size).mean(), color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    
    # color = '--m'
    # ax2.set_ylabel('trloss_te', color=color)  
    ax2.plot(df['trloss_te'].rolling(window_size).mean(), '--m')
    ax2.plot(df['trloss_im'].rolling(window_size).mean(), '--c')
    # ax2.tick_params(axis='y', labelcolor=color)
    
    color = 'g'
    ax3.set_ylabel('elapsed(hr)', color=color)  
    ax3.plot(df['elapsed']/3600, color=color)
    ax3.tick_params(axis='y', labelcolor=color)
    
    color = 'k'
    ax4.set_ylabel('#updates', color=color)  
    ax4.plot(df['update_counter'], 'k-.')
    ax4.tick_params(axis='y', labelcolor=color)
    

    fig.tight_layout()  
    plt.show()

# %% [markdown]
# # CosineAnnealingWarmRestarts

# %% [markdown]
# ## batch size 64

# %%
plot_train('experiment3/iconclass-b16-yfcc-msclips_epochs10_as1_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 128

# %%
plot_train('experiment3/iconclass-b16-yfcc-msclips_epochs10_as2_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 256

# %%
plot_train('experiment3/iconclass-b16-yfcc-msclips_epochs10_as4_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 512

# %%
plot_train('experiment3/iconclass-b16-yfcc-msclips_epochs10_as8_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 1024

# %%
plot_train('experiment3/iconclass-b16-yfcc-msclips_epochs10_as16_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# # StepLR

# %% [markdown]
# ## batch size 64

# %%
plot_train('experiment3/iconclass-b16-yfcc-msclips_epochs10_as1_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 128

# %%
plot_train('experiment3/iconclass-b16-yfcc-msclips_epochs10_as2_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 256

# %%
#plot_train('experiment3/iconclass-b16-yfcc-msclips_epochs10_as4_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 512

# %%
#plot_train('experiment3/iconclass-b16-yfcc-msclips_epochs10_as8_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 1024

# %%
#plot_train('experiment3/iconclass-b16-yfcc-msclips_epochs10_as16_start-lr5e-4_lr-schedStepLR.pkl')
