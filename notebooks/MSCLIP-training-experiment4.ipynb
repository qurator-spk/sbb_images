# %%
# !ls experiment4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle('experiment4/iconclass-b16-yfcc-msclips_epochs10_as16_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')
df.tail()
# Out:
#        telr0     imlr0    trloss  trloss_te  trloss_im  update_counter  \
# 94  0.000497  0.000497  4.163789   4.158834   4.168745               5
# 95  0.000497  0.000497  4.164954   4.158878   4.171030               5
# 96  0.000496  0.000496  4.165804   4.158864   4.172745               6
# 97  0.000496  0.000496  4.162994   4.158891   4.167096               6
# 98  0.000496  0.000496  4.163478   4.158814   4.168141               6
#
#        elapsed
# 94  110.881908
# 95  112.003556
# 96  113.234383
# 97  114.356964
# 98  115.488965

# %%
def plot_train(file):
    
    df = pd.read_pickle(file).iloc[100:]
    
    base_size=10
    fig, ax1 = plt.subplots(figsize=(base_size,int(34/55*base_size)))
    
    ax2 = ax1.twinx()  
    ax3 = ax1.twinx()
    ax4 = ax1.twinx()
    
    ax3.spines['right'].set_position(('outward', 60))
    ax4.spines['right'].set_position(('outward', 120))
    
    window_size=50
    
    color = 'r'
    ax1.set_xlabel('batch iteration')
    ax1.set_ylabel('telr0', color=color)
    ax1.plot(df['telr0'], color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    
    color = 'b'
    ax2.set_ylabel('trloss', color=color)  
    ax2.plot(df['trloss'].rolling(window_size).mean(), color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    
    # color = '--m'
    # ax2.set_ylabel('trloss_te', color=color)  
    ax2.plot(df['trloss_te'].rolling(window_size).mean(), '--m')
    ax2.plot(df['trloss_im'].rolling(window_size).mean(), '--c')
    # ax2.tick_params(axis='y', labelcolor=color)
    
    color = 'g'
    ax3.set_ylabel('elapsed(hr)', color=color)  
    ax3.plot(df['elapsed']/3600, color=color)
    ax3.tick_params(axis='y', labelcolor=color)
    
    color = 'k'
    ax4.set_ylabel('#updates', color=color)  
    ax4.plot(df['update_counter'], 'k-.')
    ax4.tick_params(axis='y', labelcolor=color)
    

    fig.tight_layout()  
    plt.show()

# %% [markdown]
# # CosineAnnealingWarmRestarts

# %% [markdown]
# ## batch size 64

# %%
plot_train('experiment4/iconclass-b16-yfcc-msclips_epochs10_as1_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 128

# %%
plot_train('experiment4/iconclass-b16-yfcc-msclips_epochs10_as2_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 256

# %%
plot_train('experiment4/iconclass-b16-yfcc-msclips_epochs10_as4_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 512

# %%
plot_train('experiment4/iconclass-b16-yfcc-msclips_epochs10_as8_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 1024

# %%
plot_train('experiment4/iconclass-b16-yfcc-msclips_epochs10_as16_start-lr5e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# # StepLR

# %% [markdown]
# ## batch size 64

# %%
#plot_train('experiment4/iconclass-b16-yfcc-msclips_epochs10_as1_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 128

# %%
#plot_train('experiment4/iconclass-b16-yfcc-msclips_epochs10_as2_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 256

# %%
#plot_train('experiment4/iconclass-b16-yfcc-msclips_epochs10_as4_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 512

# %%
#plot_train('experiment4/iconclass-b16-yfcc-msclips_epochs10_as8_start-lr5e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 1024

# %%
plot_train('experiment4/iconclass-b16-yfcc-msclips_epochs10_as16_start-lr5e-4_lr-schedStepLR.pkl')
