# %%
# !ls experiment1
# Out:
# experiment1
# iconclass-b16-yfcc-msclips_epochs10_as16_start-lr10e-4_lr-schedCosineAnnealingWarmRestarts.pkl
# iconclass-b16-yfcc-msclips_epochs10_as16_start-lr10e-4_lr-schedStepLR.pkl
# iconclass-b16-yfcc-msclips_epochs10_as1_start-lr10e-4_lr-schedCosineAnnealingWarmRestarts.pkl
# iconclass-b16-yfcc-msclips_epochs10_as1_start-lr10e-4_lr-schedStepLR.pkl
# iconclass-b16-yfcc-msclips_epochs10_as2_start-lr10e-4_lr-schedCosineAnnealingWarmRestarts.pkl
# iconclass-b16-yfcc-msclips_epochs10_as2_start-lr10e-4_lr-schedStepLR.pkl
# iconclass-b16-yfcc-msclips_epochs10_as4_start-lr10e-4_lr-schedCosineAnnealingWarmRestarts.pkl
# iconclass-b16-yfcc-msclips_epochs10_as4_start-lr10e-4_lr-schedStepLR.pkl
# iconclass-b16-yfcc-msclips_epochs10_as8_start-lr10e-4_lr-schedCosineAnnealingWarmRestarts.pkl
# iconclass-b16-yfcc-msclips_epochs10_as8_start-lr10e-4_lr-schedStepLR.pkl

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle('experiment1/iconclass-b16-yfcc-msclips_epochs10_as1_start-lr10e-4_lr-schedCosineAnnealingWarmRestarts.pkl')
df
# Out:
#                 lr0    trloss  update_counter   elapsed
# 0      1.000000e-03  9.689610               0 -0.001671
# 1      1.000000e-03  5.260706               1 -0.001663
# 2      9.999987e-04  4.338073               2 -0.001675
# 3      9.999947e-04  4.273151               3 -0.001626
# 4      9.999880e-04  4.202172               4 -0.001544
# ...             ...       ...             ...       ...
# 13585  4.809461e-08  4.158883           13585 -0.001685
# 13586  3.339920e-08  4.158883           13586 -0.001661
# 13587  2.137557e-08  4.158883           13587 -0.001712
# 13588  1.202380e-08  4.158883           13588 -0.001664
# 13589  5.343921e-09  4.158883           13589 -0.001678
#
# [13590 rows x 4 columns]

# %%
def plot_train(file):
    
    df = pd.read_pickle(file)
    
    base_size=10
    fig, ax1 = plt.subplots(figsize=(base_size,int(34/55*base_size)))
    
    ax2 = ax1.twinx()  
    ax3 = ax1.twinx()
    #
    ax3.spines['right'].set_position(('outward', 60))
    
    color = 'r'
    ax1.set_xlabel('batch iteration')
    ax1.set_ylabel('lr0', color=color)
    ax1.plot(df['lr0'], color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    
    color = 'b'
    ax2.set_ylabel('trloss', color=color)  
    ax2.plot(df['trloss'].rolling(100).mean(), color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    
    #color = 'g'
    #ax1.set_xlabel('batch iteration')
    #ax3.set_ylabel('elapsed', color=color)  
    #ax3.plot(df['elapsed'].cumsum(), color=color)
    #ax3.tick_params(axis='y', labelcolor=color)
    
    color = 'k'
    ax3.set_ylabel('update_counter', color=color)  
    ax3.plot(df['update_counter'], color=color)
    ax3.tick_params(axis='y', labelcolor=color)
    

    fig.tight_layout()  
    plt.show()

# %% [markdown]
# # CosineAnnealingWarmRestarts

# %% [markdown]
# ## batch size 64

# %%
plot_train('experiment1/iconclass-b16-yfcc-msclips_epochs10_as1_start-lr10e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 128

# %%
plot_train('experiment1/iconclass-b16-yfcc-msclips_epochs10_as2_start-lr10e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 256

# %%
plot_train('experiment1/iconclass-b16-yfcc-msclips_epochs10_as4_start-lr10e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 512

# %%
plot_train('experiment1/iconclass-b16-yfcc-msclips_epochs10_as8_start-lr10e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# ## batch size 1024

# %%
plot_train('experiment1/iconclass-b16-yfcc-msclips_epochs10_as16_start-lr10e-4_lr-schedCosineAnnealingWarmRestarts.pkl')

# %% [markdown]
# # StepLR

# %% [markdown]
# ## batch size 64

# %%
plot_train('experiment1/iconclass-b16-yfcc-msclips_epochs10_as1_start-lr10e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 128

# %%
plot_train('experiment1/iconclass-b16-yfcc-msclips_epochs10_as2_start-lr10e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 256

# %%
plot_train('experiment1/iconclass-b16-yfcc-msclips_epochs10_as4_start-lr10e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 512

# %%
plot_train('experiment1/iconclass-b16-yfcc-msclips_epochs10_as8_start-lr10e-4_lr-schedStepLR.pkl')

# %% [markdown]
# ## batch size 1024

# %%
plot_train('experiment1/iconclass-b16-yfcc-msclips_epochs10_as16_start-lr10e-4_lr-schedStepLR.pkl')
